# %% [markdown]
# # Machine Learning
# - by Professor Ibrahim Pour
# - Sharif University of Technology
# - Fall 2024
# - Sadegh Pouriyan Zadeh

# %% [markdown]
# ## Homework 1: Reducing Image Dimensions

# %% [markdown]
# ### Requirements:
# 1. Load a color image and convert it to grayscale.
# 2. Convert it into an array and obtain its dimensions.
# 3. Reduce the dimensions using:
#    - Pixel removal
#    - Averaging of pixels
#    - Interpolation techniques
# 4. Display and compare the original and resized images.
# 5. Write clean, well-commented code using sections like comments, headings, and docstrings.

# %%
from homework.first.image_utils import ImageEditor

# %%
image_path = "assets/me.jpg"
image_editor = ImageEditor(image_path)

# %%
reduction_result = image_editor.downsample(25)
image_editor.display_single_reduction(reduction_result=reduction_result)

# %%
reduction_result = image_editor.average_pool(25)
image_editor.display_single_reduction(reduction_result=reduction_result)

# %%
reduction_result = image_editor.interpolate(new_height=100, new_width=100)
image_editor.display_single_reduction(reduction_result=reduction_result)

# %%
# run this to see all reductions
image_editor.display_all_reductions()

# %% [markdown]
# ## Homework 2:
